# %%
# imports 

import pandas as pd 
import numpy as np

# %%
data = pd.read_excel('../data/Cat_personality_data.xlsx')

# %%
data
# Out:
#       Personality1_Vigilant  Personality2_Stable  Personality3_Bold  \
# 0                         6                    5                  7
# 1                         7                    3                  4
# 2                         7                    5                  7
# 3                         7                    4                  1
# 4                         5                    7                  7
# ...                     ...                  ...                ...
# 2797                      5                    6                  4
# 2798                      5                    7                  6
# 2799                      6                    5                  5
# 2800                      6                    6                  5
# 2801                      7                    6                  5
#
#       Personality4_Clumsy  Personality5_Defiant  Personality6_Gentle  \
# 0                       5                     5                    6
# ...
